# %% [markdown]
# <a href="https://colab.research.google.com/github/canye7/ChatGLM2-6B/blob/main/Colab-WebUI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GPT-SoVITS WebUI

# %% [markdown]
# ## Env Setup (Run Once Only)
# ## 环境配置, 只需运行一次

# %% [markdown]
# ### 1.

# %%
# %%writefile /content/setup.sh
# set -e
#
# cd /content
#
# git clone https://github.com/RVC-Boss/GPT-SoVITS.git
#
# cd GPT-SoVITS
#
# if conda env list | awk '{print $1}' | grep -Fxq "GPTSoVITS"; then
#     :
# else
#     conda create -n GPTSoVITS python=3.10 -y
# fi
#
# source activate GPTSoVITS
#
# pip install ipykernel
#
# bash install.sh --device CU126 --source HF --download-uvr5

# %% [markdown]
# ### 2.

# %%
# %pip install -q condacolab
import condacolab
condacolab.install_from_url("https://repo.anaconda.com/archive/Anaconda3-2024.10-1-Linux-x86_64.sh")
# !cd /content && bash setup.sh

# %% [markdown]
# ## Launch WebUI
# ## 启动 WebUI

# %%
# !cd /content/GPT-SoVITS && source activate GPTSoVITS && export is_share=True && python webui.py
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Running on local URL:  http://0.0.0.0:9874
# Running on public URL: https://cce8652b89662a875c.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# "/usr/local/envs/GPTSoVITS/bin/python" -s tools/uvr5/webui.py "cuda:0" True 9873 True
# /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/requests/__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (6.0.0.post1)/charset_normalizer (3.4.4) doesn't match a supported version!
#   warnings.warn(
# Running on local URL:  http://0.0.0.0:9873
# Running on public URL: https://f7bdffc08066cb27c8.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# ...

# %%
# 降级PyTorch到2.3.0（兼容CUDA 12.8）
# !source activate GPTSoVITS && pip install torch==2.3.0 torchaudio==2.3.0 --index-url https://download.pytorch.org/whl/cu128 --force-reinstall
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Looking in indexes: https://download.pytorch.org/whl/cu128
# ERROR: Could not find a version that satisfies the requirement torch==2.3.0 (from versions: 2.7.0+cu128, 2.7.1+cu128, 2.8.0+cu128, 2.9.0+cu128, 2.9.1+cu128, 2.10.0+cu128)
# ERROR: No matching distribution found for torch==2.3.0

# %%
# 第一步：激活环境（仅执行一次）
# !source activate GPTSoVITS

# 第二步：用Python代码查版本（直接写Python，不加!）
import torch
import torchaudio
import requests
import urllib3
import charset_normalizer

# 打印版本信息
print(f"PyTorch 版本: {torch.__version__}")
print(f"torchaudio 版本: {torchaudio.__version__}")
print(f"CUDA 可用: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA 版本: {torch.version.cuda}")
print(f"requests 版本: {requests.__version__}")
print(f"urllib3 版本: {urllib3.__version__}")
print(f"charset-normalizer 版本: {charset_normalizer.__version__}")
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# PyTorch 版本: 2.10.0+cu128
# torchaudio 版本: 2.10.0+cu128
# CUDA 可用: True
# CUDA 版本: 12.8
# requests 版本: 2.32.3
# urllib3 版本: 2.2.3
# charset-normalizer 版本: 3.3.2
